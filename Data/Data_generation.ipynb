# %%
# %pip install faker
# Out:
# Requirement already satisfied: faker in /Users/kunal.gaurav/Documents/Cursor/Telecom IoT_lakebase_aap_dash/.venv/lib/python3.11/site-packages (38.2.0)
# Requirement already satisfied: tzdata in /Users/kunal.gaurav/Documents/Cursor/Telecom IoT_lakebase_aap_dash/.venv/lib/python3.11/site-packages (from faker) (2025.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %run ./data_store_variables
# Out:
# ================================================================================
# 📋 DATA CONFIGURATION VARIABLES
# ================================================================================
# Project Name:        Telecom_IoT_Dashboard
# Databricks User:     kunal.gaurav@databricks.com
# Clean Username:      kunal-gaurav
# Catalog:             kunal
# Schema:              Telcom
# Volume Name:         iot_data_volume
# Volume Path:         /Volumes/kunal/Telcom/iot_data_volume
# Table Name:          iot_data
# Full Table Name:     kunal.Telcom.iot_data
#
# ================================================================================
# 🗄️  LAKEBASE CONFIGURATION VARIABLES
# ================================================================================
# Instance Name:       kunal-gaurav-lakebase-instance
# Instance Capacity:   CU_1
# Lakebase Catalog:    pg_lakebase_kunal-gaurav
# Synced Table:        kunal.Telcom.iot_data_synced
# PG Table:            kunal.Telcom.iot_metadata
# ================================================================================
# ✅ Catalog 'kunal' ready
# ✅ Schema 'kunal.Telcom' ready
# ✅ Volume '/Volumes/kunal/Telcom/iot_data_volume' ready
# ✅ Table 'kunal.Telcom.iot_data' ready

# %%
import random
import time
import json
import datetime
from faker import Faker

fake = Faker()

def generate_record():
    return {
        "tower_id": f"TWR-{random.randint(1000, 9999)}",
        "region": random.choice(["North", "South", "East", "West"]),
        "timestamp": datetime.datetime.utcnow().isoformat(),
        "data_usage_mb": round(random.uniform(50, 5000), 2),
        "call_drop_rate": round(random.uniform(0, 5), 2),
        "active_users": random.randint(100, 2000)
    }

print(f"📊 Starting Telecom Tower Data Generation")
print(f"📁 Target Volume: {VOLUME_PATH}")
print(f"⏰ Generating data continuously (press stop to end)...")
print("-" * 60)

if __name__ == "__main__":
    count = 0
    while True:
        count += 1
        record = generate_record()
        timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S_%f")
        file_path = f"{VOLUME_PATH}/IOT_LOGS/iot_logs_{timestamp}.json"
        
        # Use dbutils to write to the file
        dbutils.fs.put(file_path, json.dumps(record), overwrite=True)
        
        # Print progress every 10 records
        if count % 10 == 0:
            print(f"✅ Generated {count} records | Latest: {record['tower_id']} - Region: {record['region']}")
        
        time.sleep(1)
# Out:
# 📊 Starting Telecom Tower Data Generation
# 📁 Target Volume: /Volumes/kunal/Telcom/iot_data_volume
# ⏰ Generating data continuously (press stop to end)...
# ------------------------------------------------------------
# ✅ Generated 10 records | Latest: TWR-8283 - Region: West
# ✅ Generated 20 records | Latest: TWR-2259 - Region: South
# ✅ Generated 30 records | Latest: TWR-8769 - Region: East
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 33
#      30 file_path = f"{VOLUME_PATH}/IOT_LOGS/iot_logs_{timestamp}.json"
#      32 # Use dbutils to write to the file
# ---> 33 dbutils.fs.put(file_path, json.dumps(record), overwrite=True)
#      35 # Print progress every 10 records
#      36 if count % 10 == 0:
#
# File ~/Documents/Cursor/Telecom IoT_lakebase_aap_dash/.venv/lib/python3.11/site-packages/databricks/sdk/dbutils.py:81, in _FsUtil.put(self, file, contents, overwrite)
#      79 def put(self, file: str, contents: str, overwrite: bool = False) -> bool:
#      80     """Writes the given String out to a file, encoded in UTF-8"""
# ---> 81     with self._dbfs.open(file, write=True, overwrite=overwrite) as f:
#      82         f.write(contents.encode("utf8"))
#      83     return True
#
# File ~/Documents/Cursor/Telecom IoT_lakebase_aap_dash/.venv/lib/python3.11/site-packages/databricks/sdk/mixins/files.py:311, in _VolumesIO.__exit__(self, _VolumesIO__t, _VolumesIO__value, _VolumesIO__traceback)
#     310 def __exit__(self, __t, __value, __traceback):
# --> 311     self.close()
#
# File ~/Documents/Cursor/Telecom IoT_lakebase_aap_dash/.venv/lib/python3.11/site-packages/databricks/sdk/mixins/files.py:238, in _VolumesIO.close(self)
#     236 if self._write:
#     237     to_write = b"".join(self._buffer)
# --> 238     self._api.upload(
#     239         self._path,
#     240         contents=BytesIO(to_write),
#     241         overwrite=self._overwrite,
#     242     )
#     243 elif self._read:
#     244     self._read_handle.close()
#
# File ~/Documents/Cursor/Telecom IoT_lakebase_aap_dash/.venv/lib/python3.11/site-packages/databricks/sdk/service/files.py:953, in FilesAPI.upload(self, file_path, contents, overwrite)
#     948     query["overwrite"] = overwrite
#     949 headers = {
#     950     "Content-Type": "application/octet-stream",
#     951 }
# --> 953 self._api.do(
#     954     "PUT",
#     955     f"/api/2.0/fs/files{_escape_multi_segment_path_parameter(file_path)}",
#     956     query=query,
#     957     headers=headers,
#     958     data=contents,
#     959 )
#
# File ~/Documents/Cursor/Telecom IoT_lakebase_aap_dash/.venv/lib/python3.11/site-packages/databricks/sdk/core.py:85, in ApiClient.do(self, method, path, url, query, headers, body, raw, files, data, auth, response_headers)
#      83     path = re.sub("^/api/2.0/fs/files//", "/api/2.0/fs/files/", path)
#      84     url = f"{self._cfg.host}{path}"
# ---> 85 return self._api_client.do(
#      86     method=method,
#      87     url=url,
#      88     query=query,
#      89     headers=headers,
#      90     body=body,
#      91     raw=raw,
#      92     files=files,
#      93     data=data,
#      94     auth=auth,
#      95     response_headers=response_headers,
#      96 )
#
# File ~/Documents/Cursor/Telecom IoT_lakebase_aap_dash/.venv/lib/python3.11/site-packages/databricks/sdk/_base_client.py:199, in _BaseClient.do(self, method, url, query, headers, body, raw, files, data, auth, response_headers)
#     196     logger.debug(f"Retry disabled for non-seekable stream: type={type(data)}")
#     197     call = self._perform
# --> 199 response = call(
#     200     method,
#     201     url,
#     202     query=query,
#     203     headers=headers,
#     204     body=body,
#     205     raw=raw,
#     206     files=files,
#     207     data=data,
#     208     auth=auth,
#     209 )
#     211 resp = dict()
#     212 for header in response_headers if response_headers else []:
#
# File ~/Documents/Cursor/Telecom IoT_lakebase_aap_dash/.venv/lib/python3.11/site-packages/databricks/sdk/retries.py:38, in retried.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      36 while clock.time() < deadline:
#      37     try:
# ---> 38         return func(*args, **kwargs)
#      39     except Exception as err:
#      40         last_err = err
#
# File ~/Documents/Cursor/Telecom IoT_lakebase_aap_dash/.venv/lib/python3.11/site-packages/databricks/sdk/_base_client.py:286, in _BaseClient._perform(self, method, url, query, headers, body, raw, files, data, auth)
#     274 def _perform(
#     275     self,
#     276     method: str,
#    (...)    284     auth: Callable[[requests.PreparedRequest], requests.PreparedRequest] = None,
#     285 ):
# --> 286     response = self._session.request(
#     287         method,
#     288         url,
#     289         params=self._fix_query_string(query),
#     290         json=body,
#     291         headers=headers,
#     292         files=files,
#     293         data=data,
#     294         auth=auth,
#     295         stream=raw,
#     296         timeout=self._http_timeout_seconds,
#     297     )
#     298     self._record_request_log(response, raw=raw or data is not None or files is not None)
#     299     error = self._error_parser.get_api_error(response)
#
# File ~/Documents/Cursor/Telecom IoT_lakebase_aap_dash/.venv/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Documents/Cursor/Telecom IoT_lakebase_aap_dash/.venv/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/Documents/Cursor/Telecom IoT_lakebase_aap_dash/.venv/lib/python3.11/site-packages/requests/adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     641     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#     659     raise ConnectionError(err, request=request)
#
# File ~/Documents/Cursor/Telecom IoT_lakebase_aap_dash/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~/Documents/Cursor/Telecom IoT_lakebase_aap_dash/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/Documents/Cursor/Telecom IoT_lakebase_aap_dash/.venv/lib/python3.11/site-packages/urllib3/connection.py:565, in HTTPConnection.getresponse(self)
#     562 _shutdown = getattr(self.sock, "shutdown", None)
#     564 # Get the response from http.client.HTTPConnection
# --> 565 httplib_response = super().getresponse()
#     567 try:
#     568     assert_header_parsing(httplib_response.msg)
#
# File ~/.local/share/uv/python/cpython-3.11.14-macos-aarch64-none/lib/python3.11/http/client.py:1395, in HTTPConnection.getresponse(self)
#    1393 try:
#    1394     try:
# -> 1395         response.begin()
#    1396     except ConnectionError:
#    1397         self.close()
#
# File ~/.local/share/uv/python/cpython-3.11.14-macos-aarch64-none/lib/python3.11/http/client.py:325, in HTTPResponse.begin(self)
#     323 # read until we get a non-100 response
#     324 while True:
# --> 325     version, status, reason = self._read_status()
#     326     if status != CONTINUE:
#     327         break
#
# File ~/.local/share/uv/python/cpython-3.11.14-macos-aarch64-none/lib/python3.11/http/client.py:286, in HTTPResponse._read_status(self)
#     285 def _read_status(self):
# --> 286     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     287     if len(line) > _MAXLINE:
#     288         raise LineTooLong("status line")
#
# File ~/.local/share/uv/python/cpython-3.11.14-macos-aarch64-none/lib/python3.11/socket.py:718, in SocketIO.readinto(self, b)
#     716 while True:
#     717     try:
# --> 718         return self._sock.recv_into(b)
#     719     except timeout:
#     720         self._timeout_occurred = True
#
# File ~/.local/share/uv/python/cpython-3.11.14-macos-aarch64-none/lib/python3.11/ssl.py:1314, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1310     if flags != 0:
#    1311         raise ValueError(
#    1312           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1313           self.__class__)
# -> 1314     return self.read(nbytes, buffer)
#    1315 else:
#    1316     return super().recv_into(buffer, nbytes, flags)
#
# File ~/.local/share/uv/python/cpython-3.11.14-macos-aarch64-none/lib/python3.11/ssl.py:1166, in SSLSocket.read(self, len, buffer)
#    1164 try:
#    1165     if buffer is not None:
# -> 1166         return self._sslobj.read(len, buffer)
#    1167     else:
#    1168         return self._sslobj.read(len)
#
# KeyboardInterrupt:
